# %% [markdown]
# <a href="https://colab.research.google.com/github/francisco-reis-ramos/dados-imobiliarios-com-pandas/blob/main/Pandas_Conhecendo_a_Biblioteca.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Conhecendo a base de dados

# %% [markdown]
# ## Importando os dados

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/base-de-dados/aluguel.csv'
pd.read_csv(url)

# Perceba na saída abaixo que a base está um pouco desconfigurada. Isso ocorre pq o read_csv por padrão considera a vírgula como elemento separador.
# Out:
#       Tipo;Bairro;Quartos;Vagas;Suites;Area;Valor;Condominio;IPTU
# 0              Quitinete;Copacabana;1;0;0;40;1700;500;60
# 1                  Casa;Jardim Botânico;2;0;1;100;7000;;
# 2      Conjunto Comercial/Sala;Barra da Tijuca;0;4;0;...
# 3                 Apartamento;Centro;1;0;0;15;800;390;20
# 4             Apartamento;Higienópolis;1;0;0;48;800;230;
# ...                                                  ...
# 32955               Quitinete;Centro;0;0;0;27;800;350;25
# 32956       Apartamento;Jacarepaguá;3;1;2;78;1800;800;40
# 32957  Apartamento;São Francisco Xavier;2;1;0;48;1400...
# 32958              Apartamento;Leblon;2;0;0;70;3000;760;
# 32959  Conjunto Comercial/Sala;Centro;0;0;0;250;6500;...
#
# [32960 rows x 1 columns]

# %%
# Maneira de ler a base fazendo a separação correta

pd.read_csv(url,sep=';')
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# ...

# %%
# Nomeando a base de dados áo criar uma variável

dados = pd.read_csv(url,sep=';')
dados
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# ...

# %%
# Exibindo registros iniciais da tabela através do método 'head()'

dados.head(10)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
# 7       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8       Casa de Condomínio            Ramos        2      2       0    65
# 9  Conjunto Comercial/Sala           Centro        0      3       0   695
#
#      Valor  Condominio    IPTU
# 0   1700.0       500.0    60.0
# 1   7000.0         NaN     NaN
# 2   5200.0      4020.0  1111.0
# ...

# %%
# Exibindo registros finais da tabela através do método 'tail()'

dados.tail(7)
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 32953              Apartamento                 Méier        2      0       0
# 32954              Box/Garagem                Centro        0      0       0
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area    Valor  Condominio    IPTU
# 32953    70    900.0       490.0    48.0
# 32954   755  14000.0         NaN     NaN
# 32955    27    800.0       350.0    25.0
# 32956    78   1800.0       800.0    40.0
# 32957    48   1400.0       509.0    37.0
# 32958    70   3000.0       760.0     NaN
# 32959   250   6500.0      4206.0  1109.0

# %%
type(dados)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Características gerais da base de dados

# %%
# Verificando a quantidade de linhas e colunas da base

dados.shape
# Out:
# (32960, 9)

# %%
# Verificando os nomes das colunas
dados.columns
# Out:
# Index(['Tipo', 'Bairro', 'Quartos', 'Vagas', 'Suites', 'Area', 'Valor',
#        'Condominio', 'IPTU'],
#       dtype='object')

# %%
# É importante analisar os tipos de dados de cada coluna

dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32960 entries, 0 to 32959
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        32960 non-null  object
#  1   Bairro      32960 non-null  object
#  2   Quartos     32960 non-null  int64
#  3   Vagas       32960 non-null  int64
#  4   Suites      32960 non-null  int64
#  5   Area        32960 non-null  int64
#  6   Valor       32943 non-null  float64
#  7   Condominio  28867 non-null  float64
#  8   IPTU        22723 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 2.3+ MB

# %%
# Para entender cada um dos tipos de dados que compõem os campos da tabela, vamos visualizar uma coluna de cada tipo de dados.

dados['Tipo'] # Analisando o tipo object, conclui-se que se trata de strings.
dados['Quartos'] # Analisando o tipo int64, percebe-se que se trata de dados numéricos inteiros.
dados['Valor'] # Analisando o tipo float64, percebe-se que se trata de dados decimais. Portanto, pode representar valores monetários.
# Out:
# 0        1700.0
# 1        7000.0
# 2        5200.0
# 3         800.0
# 4         800.0
#           ...
# 32955     800.0
# 32956    1800.0
# 32957    1400.0
# 32958    3000.0
# 32959    6500.0
# Name: Valor, Length: 32960, dtype: float64

# %%
# Visualizando os dados das três colunas ao mesmo tempo:

dados[['Tipo','Quartos','Valor']]
# Out:
#                           Tipo  Quartos   Valor
# 0                    Quitinete        1  1700.0
# 1                         Casa        2  7000.0
# 2      Conjunto Comercial/Sala        0  5200.0
# 3                  Apartamento        1   800.0
# 4                  Apartamento        1   800.0
# ...                        ...      ...     ...
# 32955                Quitinete        0   800.0
# 32956              Apartamento        3  1800.0
# 32957              Apartamento        2  1400.0
# 32958              Apartamento        2  3000.0
# 32959  Conjunto Comercial/Sala        0  6500.0
#
# [32960 rows x 3 columns]

# %% [markdown]
# # Análise exploratória de dados

# %% [markdown]
# ## Qual o valor médio de aluguel por tipo de imóvel?

# %%
# Calculando a média da coluna 'Valor'

dados['Valor'].mean()
# Out:
# 12952.659715265761

# %%
# Calculando os valores médios de cada coluna agrupando por tipo de imóvel.

dados.groupby('Tipo').mean(numeric_only=True)

# O groupby() é um método que sempre é utilizado acompanhado de um método de agregação.
# Importante restringir o mean() a campos numéricos '(numeric_only=True)' pois em algumas versões do Pandas a falta dessa restrição gera erros.
# Out:
#                                Quartos      Vagas     Suites          Area  \
# Tipo
# Apartamento                   2.481569   1.232388   0.875998    119.790498
# Box/Garagem                   0.060976   1.304878   0.000000     17.524390
# Casa                          3.133402   1.795243   1.258532    250.578077
# Casa Comercial                1.562264   2.203774   0.260377    372.241509
# Casa de Condomínio            4.007028   3.101406   2.864458    456.161647
# Casa de Vila                  1.927711   0.389558   0.228916     78.469880
# Chácara                       3.000000   0.000000   0.000000      0.000000
# Conjunto Comercial/Sala       0.040939   2.516801   0.010858    214.472487
# Flat                          1.415966   0.962185   0.754202     65.483193
# Galpão/Depósito/Armazém       0.043339   5.587480   0.000000   2514.810594
# Hotel                        25.500000   2.500000  12.000000    885.500000
# ...

# %%
# Calculando o valor médio em uma única coluna, nesse caso a coluna 'Valor'.

dados.groupby('Tipo')['Valor'].mean()

# Por se tratar de uma coluna numérica, não é necessário adicionar o parâmetro 'numeric_only=True'.
# Out:
# Tipo
# Apartamento                      4744.614648
# Box/Garagem                      1899.756098
# Casa                             6793.454922
# Casa Comercial                  14478.264151
# Casa de Condomínio              11952.061245
# Casa de Vila                     1574.369478
# Chácara                          4900.000000
# Conjunto Comercial/Sala         14715.045521
# Flat                             4546.189076
# Galpão/Depósito/Armazém         53407.062600
# Hotel                           25000.000000
# Indústria                      120000.000000
# Loft                             2557.882353
# Loja Shopping/ Ct Comercial      8126.178862
# Loja/Salão                      13769.646770
# Loteamento/Condomínio           22000.000000
# Pousada/Chalé                    1480.000000
# Prédio Inteiro                 498637.239203
# Quitinete                        1246.840909
# Studio                           2400.000000
# Sítio                           12499.000000
# ...

# %%
# Realizando o cálculo anterior ordenando a saída de maneira crescente.

dados.groupby('Tipo')[['Valor']].mean().sort_values('Valor')

# O uso de colchetes duplos faz com que seja retornado um DataFrame. Por outro lado, colchetes simples retornam uma Series.
# Out:
#                                      Valor
# Tipo
# Quitinete                      1246.840909
# Pousada/Chalé                  1480.000000
# Casa de Vila                   1574.369478
# Box/Garagem                    1899.756098
# Studio                         2400.000000
# Loft                           2557.882353
# Flat                           4546.189076
# Apartamento                    4744.614648
# Chácara                        4900.000000
# Casa                           6793.454922
# Loja Shopping/ Ct Comercial    8126.178862
# Casa de Condomínio            11952.061245
# Sítio                         12499.000000
# Loja/Salão                    13769.646770
# Casa Comercial                14478.264151
# Conjunto Comercial/Sala       14715.045521
# Loteamento/Condomínio         22000.000000
# Hotel                         25000.000000
# Terreno Padrão                32567.714286
# Galpão/Depósito/Armazém       53407.062600
# Indústria                    120000.000000
# ...

# %%
df_valor_tipo = dados.groupby('Tipo')[['Valor']].mean().sort_values('Valor')

# %%
df_valor_tipo.plot(kind='barh', figsize=(14, 10), color ='purple')
# Out:
# <Axes: ylabel='Tipo'>

# %% [markdown]
# ## Removendo os imóveis comerciais

# %%
# Como a análise se restringe aos imóveis residenciais, será necessário remover os imóveis comerciais da base.
# Primeiro, vamos exibir de maneira distinta os valores da coluna 'Tipo'.

dados.Tipo.unique()
# Out:
# array(['Quitinete', 'Casa', 'Conjunto Comercial/Sala', 'Apartamento',
#        'Casa de Condomínio', 'Prédio Inteiro', 'Flat', 'Loja/Salão',
#        'Galpão/Depósito/Armazém', 'Casa Comercial', 'Casa de Vila',
#        'Terreno Padrão', 'Box/Garagem', 'Loft',
#        'Loja Shopping/ Ct Comercial', 'Chácara', 'Loteamento/Condomínio',
#        'Sítio', 'Pousada/Chalé', 'Studio', 'Hotel', 'Indústria'],
#       dtype=object)

# %%
# Agora, vamos criar uma lista com os tipos de imóveis comerciais

imoveis_comerciais = ['Conjunto Comercial/Sala',
                      'Prédio Inteiro','Loja/Salão',
                      'Galpão/Depósito/Armazém', 'Casa Comercial',
                      'Terreno Padrão', 'Box/Garagem',
                      'Loja Shopping/ Ct Comercial', 'Chácara', 'Loteamento/Condomínio',
                      'Sítio', 'Pousada/Chalé', 'Hotel', 'Indústria']

# %%
# Selecionando linhas de um dataframe com o método query().

dados.query('@imoveis_comerciais in Tipo')

# Ao passar uma variável para uma expressão dentro do método query é necessário incluir o sinal @ antes.
# Out:
#                           Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 2      Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 9      Conjunto Comercial/Sala           Centro        0      3       0   695
# 16              Prédio Inteiro         Botafogo        0      0       0   536
# 26     Conjunto Comercial/Sala    São Cristóvão        0      1       0    25
# 29                  Loja/Salão     Campo Grande        0      1       0    35
# ...                        ...              ...      ...    ...     ...   ...
# 32942  Conjunto Comercial/Sala  Barra da Tijuca        0      1       0    55
# 32946  Conjunto Comercial/Sala           Centro        0      0       0   140
# 32948  Conjunto Comercial/Sala           Centro        0      0       0    32
# 32954              Box/Garagem           Centro        0      0       0   755
# 32959  Conjunto Comercial/Sala           Centro        0      0       0   250
#
# ...

# %%
# Para selecionar as linhas que correspondem a imóveis não comerciais basta inverter o sentido da expressão acima.

dados.query('@imoveis_comerciais not in Tipo')
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 3      Apartamento                Centro        1      0       0    15
# 4      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 32953  Apartamento                 Méier        2      0       0    70
# 32955    Quitinete                Centro        0      0       0    27
# 32956  Apartamento           Jacarepaguá        3      1       2    78
# 32957  Apartamento  São Francisco Xavier        2      1       0    48
# 32958  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         NaN   NaN
# ...

# %%
# Criando um novo dataframe apenas com imóveis residenciais

df = dados.query('@imoveis_comerciais not in Tipo')

# %%
df.Tipo.unique()
# Out:
# array(['Quitinete', 'Casa', 'Apartamento', 'Casa de Condomínio', 'Flat',
#        'Casa de Vila', 'Loft', 'Studio'], dtype=object)

# %%
df_preco_tipo = df.groupby('Tipo')[['Valor']].mean().sort_values('Valor')

# %%
df_preco_tipo.plot(kind='barh', figsize=(14,10), color='purple');

# %% [markdown]
# ## Qual o percentual de cada tipo de imóvel na nossa base de dados?

# %%
# Consultando os valores distintos da coluna 'Tipo'.

df.Tipo.unique()
# Out:
# array(['Quitinete', 'Casa', 'Apartamento', 'Casa de Condomínio', 'Flat',
#        'Casa de Vila', 'Loft', 'Studio'], dtype=object)

# %%
# Contando quantos imóveis por tipo existem na base.

df.Tipo.value_counts()
# Out:
# Tipo
# Apartamento           19532
# Casa de Condomínio      996
# Casa                    967
# Quitinete               836
# Flat                    476
# Casa de Vila            249
# Loft                     51
# Studio                    4
# Name: count, dtype: int64

# %%
# Exibindo o percentual de imóveis por tipo.

df.Tipo.value_counts(normalize=True)
# Out:
# Tipo
# Apartamento           0.845139
# Casa de Condomínio    0.043096
# Casa                  0.041842
# Quitinete             0.036173
# Flat                  0.020596
# Casa de Vila          0.010774
# Loft                  0.002207
# Studio                0.000173
# Name: proportion, dtype: float64

# %%
# Transformando a saída em DataFrame com 'to_frame' e classificando os valores em ordem crescebte.

df.Tipo.value_counts(normalize=True).to_frame().sort_values('proportion')
# Out:
#                     proportion
# Tipo
# Studio                0.000173
# Loft                  0.002207
# Casa de Vila          0.010774
# Flat                  0.020596
# Quitinete             0.036173
# Casa                  0.041842
# Casa de Condomínio    0.043096
# Apartamento           0.845139

# %%
# Guardando a consulta em uma variável e criando um gráfico de barras verticais para representar o percentual de imóveis por tipo.

df_percentual_tipo = df.Tipo.value_counts(normalize=True).to_frame().sort_values('proportion')
df_percentual_tipo.plot(kind='bar', figsize=(10,8), color='green', xlabel='Tipos', ylabel='Percentual')
# Out:
# <Axes: xlabel='Tipos', ylabel='Percentual'>

# %% [markdown]
# ### **Selecionando apenas os imóveis do tipo apartamento**

# %%
'''
O gráfico acima demonstrou que os imóveis do tipo apartamento são amplamente predominantes na base.
Além disso, por possuírem características muito distintas, os preço de casas e apartamentos variam bastante.
Sendo assim, para uma análise mais precisa, iremos trabalhar apenas com apartamentos.
'''
df.query('Tipo == "Apartamento"')
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 3      Apartamento                Centro        1      0       0    15
# 4      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento          Vista Alegre        3      1       0    70
# 6      Apartamento              Cachambi        2      0       0    50
# 10     Apartamento                Centro        1      0       0    36
# ...            ...                   ...      ...    ...     ...   ...
# 32951  Apartamento        Vila Valqueire        2      0       0    52
# 32953  Apartamento                 Méier        2      0       0    70
# 32956  Apartamento           Jacarepaguá        3      1       2    78
# 32957  Apartamento  São Francisco Xavier        2      1       0    48
# 32958  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 3       800.0       390.0  20.0
# 4       800.0       230.0   NaN
# ...

# %%
df = df.query('Tipo == "Apartamento"')
df
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 3      Apartamento                Centro        1      0       0    15
# 4      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento          Vista Alegre        3      1       0    70
# 6      Apartamento              Cachambi        2      0       0    50
# 10     Apartamento                Centro        1      0       0    36
# ...            ...                   ...      ...    ...     ...   ...
# 32951  Apartamento        Vila Valqueire        2      0       0    52
# 32953  Apartamento                 Méier        2      0       0    70
# 32956  Apartamento           Jacarepaguá        3      1       2    78
# 32957  Apartamento  São Francisco Xavier        2      1       0    48
# 32958  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 3       800.0       390.0  20.0
# 4       800.0       230.0   NaN
# ...

# %% [markdown]
# # Tratando e filtrando os dados

# %% [markdown]
# # Lidando com dados nulos

# %%
# Primeiro vamos identificar onde estão os valores null utilizando 'isnull()'.

df.isnull()
# Out:
#         Tipo  Bairro  Quartos  Vagas  Suites   Area  Valor  Condominio   IPTU
# 3      False   False    False  False   False  False  False       False  False
# 4      False   False    False  False   False  False  False       False   True
# 5      False   False    False  False   False  False  False        True   True
# 6      False   False    False  False   False  False  False       False  False
# 10     False   False    False  False   False  False  False        True   True
# ...      ...     ...      ...    ...     ...    ...    ...         ...    ...
# 32951  False   False    False  False   False  False  False       False   True
# 32953  False   False    False  False   False  False  False       False  False
# 32956  False   False    False  False   False  False  False       False  False
# 32957  False   False    False  False   False  False  False       False  False
# 32958  False   False    False  False   False  False  False       False   True
#
# [19532 rows x 9 columns]

# %%
# Verificando a quantidade de valores null por coluna.

df.isnull().sum()

# Os valores False equivalem a zero e os valores True equivalem a 1. Portanto, os valores impressos representam quantas vezes o null ocorrem em cada coluna.
# Out:
# Tipo             0
# Bairro           0
# Quartos          0
# Vagas            0
# Suites           0
# Area             0
# Valor            7
# Condominio     745
# IPTU          5472
# dtype: int64

# %%
# Como as três colunas que possuem valores nulos são numéricas, o tratamento será feito transformando os valores em zero.
# Em outros contextos essa pode não ser a solução adequada, então pode ser necessário outro procedimento.

df.fillna(0)
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 3      Apartamento                Centro        1      0       0    15
# 4      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento          Vista Alegre        3      1       0    70
# 6      Apartamento              Cachambi        2      0       0    50
# 10     Apartamento                Centro        1      0       0    36
# ...            ...                   ...      ...    ...     ...   ...
# 32951  Apartamento        Vila Valqueire        2      0       0    52
# 32953  Apartamento                 Méier        2      0       0    70
# 32956  Apartamento           Jacarepaguá        3      1       2    78
# 32957  Apartamento  São Francisco Xavier        2      1       0    48
# 32958  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 3       800.0       390.0  20.0
# 4       800.0       230.0   0.0
# ...

# %%
df = df.fillna(0)

# %%
df.isnull().sum()

# Agora o resultado da soma de valores nulo é zero para todas as colunas.
# Out:
# Tipo          0
# Bairro        0
# Quartos       0
# Vagas         0
# Suites        0
# Area          0
# Valor         0
# Condominio    0
# IPTU          0
# dtype: int64

# %% [markdown]
# # Removendo registros
# ##### Alguns registros na base não fazem sentido e, por isso, serão removidos. São eles:
#
#
# *   Apartamentos que possuem valor de aluguel igual a zero;
# *   Apartamentos com valor do condomínio igual a zero.

# %%
# Retornando todos os registros que possuem valor de aluguel ou condomínio igual a zero.

df.query('Valor == 0 | Condominio == 0')
# Out:
#               Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 5      Apartamento     Vista Alegre        3      1       0    70  1200.0
# 10     Apartamento           Centro        1      0       0    36  1200.0
# 76     Apartamento  Barra da Tijuca        2      1       1    70     0.0
# 113    Apartamento       Praça Seca        2      0       0    80  1000.0
# 166    Apartamento    Rocha Miranda        2      1       0    50  1100.0
# ...            ...              ...      ...    ...     ...   ...     ...
# 32609  Apartamento       Copacabana        3      0       0   130  4600.0
# 32643  Apartamento        Guadalupe        1      0       0    40   550.0
# 32666  Apartamento       Bonsucesso        1      0       0    60  1000.0
# 32708  Apartamento         Flamengo        2      0       0    59  3500.0
# 32809  Apartamento        Cascadura        3      0       1    70  1200.0
#
#        Condominio  IPTU
# 5             0.0   0.0
# 10            0.0   0.0
# ...

# %%
# Retornando os índices das linhas que serão removidas da base.

df.query('Valor == 0 | Condominio == 0').index
# Out:
# Index([    5,    10,    76,   113,   166,   194,   258,   265,   275,   292,
#        ...
#        32420, 32438, 32480, 32538, 32584, 32609, 32643, 32666, 32708, 32809],
#       dtype='int64', length=752)

# %%
# Guardando os índices das linhas em branco em uma variável

registros_a_remover = df.query('Valor == 0 | Condominio == 0').index

# %%
# Removendo de 'df' os registros selecionados anteriormente.

df.drop(registros_a_remover, axis=0, inplace=True)

# O parâmetro 'axis' indica se serão removidas linhas ou colunas. Se =0, remove linhas, se =1, remove colunas.
# O parâmetro 'inplace=True' indica que as alterações sejam aplicadas de maneira definitiva no dataframe, neste caso 'df'.

# %%
# Corfirmando a remoção dos registros.

df.query('Valor == 0 | Condominio == 0')
# Out:
# Empty DataFrame
# Columns: [Tipo, Bairro, Quartos, Vagas, Suites, Area, Valor, Condominio, IPTU]
# Index: []

# %%
df.head()
# Out:
#            Tipo               Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 3   Apartamento               Centro        1      0       0    15   800.0
# 4   Apartamento         Higienópolis        1      0       0    48   800.0
# 6   Apartamento             Cachambi        2      0       0    50  1300.0
# 11  Apartamento               Grajaú        2      1       0    70  1500.0
# 12  Apartamento  Lins de Vasconcelos        3      1       1    90  1500.0
#
#     Condominio  IPTU
# 3        390.0  20.0
# 4        230.0   0.0
# 6        301.0  17.0
# 11       642.0  74.0
# 12       455.0  14.0

# %%
df.Tipo.unique()
# Out:
# array(['Apartamento'], dtype=object)

# %%
# Como 'Apartamento' é o único valor presente na coluna 'Tipo', ela será removida.

df.drop('Tipo', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18780 entries, 3 to 32958
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Bairro      18780 non-null  object
#  1   Quartos     18780 non-null  int64
#  2   Vagas       18780 non-null  int64
#  3   Suites      18780 non-null  int64
#  4   Area        18780 non-null  int64
#  5   Valor       18780 non-null  float64
#  6   Condominio  18780 non-null  float64
#  7   IPTU        18780 non-null  float64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 1.3+ MB

# %% [markdown]
# ## Filtros

# %% [markdown]
# ### **1. Apartamentos que possuem `1 quarto` e `aluguel menor que 1200`**

# %%
# Filtrando apartamentos que possuam apenas 1 quarto.

df['Quartos'] == 1

# Essa seleção retornou uma Series de valores booleanos onde as linhas com valor 'True' representam os apartamentos que possuem 1 quarto.
# Out:
# 3         True
# 4         True
# 6        False
# 11       False
# 12       False
#          ...
# 32951    False
# 32953    False
# 32956    False
# 32957    False
# 32958    False
# Name: Quartos, Length: 18780, dtype: bool

# %%
# Vamos armazenar a seleção acima em uma variável. Depois disso, vamos selecionar os apartamentos através dessa variável, que será utilizada como parâmetro.

selecao1 = df['Quartos'] == 1
df[selecao1]

# Os valores falsos de uma Series booleana não são exibidos na seleção de um DataFrame quando a Series é passada como parâmetro.
# Out:
#                 Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  \
# 3               Centro        1      0       0    15   800.0       390.0
# 4         Higienópolis        1      0       0    48   800.0       230.0
# 13          Copacabana        1      0       1    40  2000.0       561.0
# 28              Tijuca        1      0       0    48   750.0       772.0
# 54              Centro        1      0       0    27   750.0       371.0
# ...                ...      ...    ...     ...   ...     ...         ...
# 32918          Ipanema        1      0       0    55  2000.0       630.0
# 32922  Barra da Tijuca        1      1       0    62  1700.0       945.0
# 32935           Leblon        1      1       1    50  4300.0      1730.0
# 32938       Copacabana        1      0       0    50  1950.0       450.0
# 32950           Tijuca        1      0       0    28  1000.0       360.0
#
#         IPTU
# 3       20.0
# 4        0.0
# 13      50.0
# 28      25.0
# 54      19.0
# ...

# %%
# Filtrando apartamentos com aluguel menor que 1200.

df['Valor'] < 1200
# Out:
# 3         True
# 4         True
# 6        False
# 11       False
# 12       False
#          ...
# 32951     True
# 32953     True
# 32956    False
# 32957    False
# 32958    False
# Name: Valor, Length: 18780, dtype: bool

# %%
selecao2 = df['Valor'] < 1200
df[selecao2]
# Out:
#                         Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 3                       Centro        1      0       0    15   800.0
# 4                 Higienópolis        1      0       0    48   800.0
# 19     Freguesia (Jacarepaguá)        3      0       0    54   950.0
# 23                      Olaria        3      1       0    68  1000.0
# 28                      Tijuca        1      0       0    48   750.0
# ...                        ...      ...    ...     ...   ...     ...
# 32925                 Campinho        2      0       0    63   800.0
# 32930  Freguesia (Jacarepaguá)        2      1       0    60   500.0
# 32950                   Tijuca        1      0       0    28  1000.0
# 32951           Vila Valqueire        2      0       0    52  1000.0
# 32953                    Méier        2      0       0    70   900.0
#
#        Condominio   IPTU
# 3           390.0   20.0
# 4           230.0    0.0
# 19          300.0   28.0
# 23          670.0    0.0
# ...

# %%
# Como o objetivo é apresentar os dados das duas seleções em uma só seleção será criada uma seleção que exiba o DataFrame 'df' com esses dois filtros.

selecao_final = (selecao1) & (selecao2)
df[selecao_final]
# Out:
#              Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio   IPTU
# 3            Centro        1      0       0    15   800.0       390.0   20.0
# 4      Higienópolis        1      0       0    48   800.0       230.0    0.0
# 28           Tijuca        1      0       0    48   750.0       772.0   25.0
# 54           Centro        1      0       0    27   750.0       371.0   19.0
# 94           Centro        1      1       0    37  1100.0       540.0  900.0
# ...             ...      ...    ...     ...   ...     ...         ...    ...
# 32596        Grajaú        1      0       1    37  1000.0       200.0    0.0
# 32617     Pechincha        1      0       1    69   900.0       640.0  126.0
# 32627        Glória        1      0       0    46  1100.0       453.0   32.0
# 32714      Botafogo        1      0       0    21  1000.0       282.0   25.0
# 32950        Tijuca        1      0       0    28  1000.0       360.0   25.0
#
# [499 rows x 8 columns]

# %%
df_1 = df[selecao_final]

# %% [markdown]
# ### **2. `Apartamentos` que possuem pelo menos `2 quartos`, `aluguel menor que 3000` e `area maior que 70`**

# %% [markdown]
# ## Salvando os dados

# %% [markdown]
# # Manipulando os dados

# %% [markdown]
# ## Criando colunas numéricas

# %% [markdown]
# ## Criando colunas categóricas
